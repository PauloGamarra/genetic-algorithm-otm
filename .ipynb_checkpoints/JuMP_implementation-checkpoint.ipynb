# %% [markdown]
# # Importing packages

# %%
using JuMP
using SCIP
using Formatting
using GLPKMathProgInterface

# %% [markdown]
# # Defining experiment parameters

# %%
instances_dir = "Problema2"
time_limit = 60 * 60; # seconds

# %% [markdown]
# # Running Experiment

# %%
# instance_files = readdir(instances_dir)
instance_files = ["smt_50_250.dat"]

for instance_file in instance_files

    print("Running $instance_file\n")
    
    instance_file_path = joinpath.(instances_dir, instance_file)

    f = open(instance_file_path, "r")         

    lines = readlines(f)

    close(f)

    n, m, s, t = [parse(Int, num_char) for num_char in split(lines[1])]

    V = Array(1:n)
    V_st = copy(V)
    deleteat!(V_st, V_st .== s)
    deleteat!(V_st, V_st .== t)

    D = zeros(Int64, (n, n))
    G = zeros(Int64, (n, n))
    P = zeros(Int64, (n, n, n))

    for i in 2:m+1
        u, v, d = [parse(Int, num_char) for num_char in split(lines[i])]
        D[u, v] = d
        D[v, u] = d
        G[u, v] = 1
        G[v, u] = 1
    end

    for i in 1:n
        for j in 1:n
            for k in 1:n
                P[i,j,k] = abs(D[i,j] - D[j,k])
            end
        end
    end

    M = maximum(P);

    # Defining Model

    model = Model(SCIP.Optimizer)

    set_time_limit_sec(model, time_limit);

    @variable(model, C[1:n, 1:n], Bin)
    @variable(model, Q[1:n, 1:n, 1:n], Bin)
    @variable(model, p >= 0, Int)

    @objective(model, Min, p)

    # Restrições para gerar um caminho C subgrafo de G
    @constraint(model, sum(C[j,s] for j = 1:n) == 0)
    @constraint(model, sum(C[s,j] for j = 1:n) == 1)
    @constraint(model, sum(C[j,t] for j = 1:n) == 1)
    @constraint(model, sum(C[t,j] for j = 1:n) == 0)
    @constraint(model, [i in V_st], sum(C[j,i] for j = 1:n) <= 1)
    @constraint(model, [i in V_st], sum(C[j,i] for j = 1:n) - sum(C[i,j] for j = 1:n) == 0)
    @constraint(model, [i = 1:n, j=1:n], C[i,j] - G[i,j] <= 0)

    # Restrições para que  Q_{ijk} = C_{ij} ^ C_{jk}
    @constraint(model, [i = 1:n, j=1:n, k=1:n], Q[i,j,k] <= (C[i,j] + C[j,k])/2)
    @constraint(model, [i = 1:n, j=1:n, k=1:n], Q[i,j,k] >= C[i,j] + C[j,k] - 1)

    # Restrições para que p seja o passo máximo do caminho selecionado
    @constraint(model, [i = 1:n, j=1:n, k=1:n], p >= P[i,j,k] + (-M * (1 - Q[i,j,k])));

    # Optimizing

    x = @timed optimize!(model)


    optimization_time = x[2]
    proved_optimality = termination_status(model) == MOI.OPTIMAL
    timeout = termination_status(model) == MOI.TIME_LIMIT
    
    print("\n<--------------------------------------------------------------------->\n\n")
    print("Results for $instance_file:\n")
    print("\toptimization_time: $optimization_time\n")
    print("\tobjective_value: ")
    print(objective_value(model))
    print("\n")
    print("\tproved_optimality: $proved_optimality\n")
    print("\ttimeout: $timeout\n")
    print("\n<--------------------------------------------------------------------->\n")

end
# Out:
# Running smt_7_6.dat
# presolving:
# (round 1, fast)       371 del vars, 760 del conss, 0 add conss, 365 chg bounds, 115 chg sides, 115 chg coeffs, 0 upgd conss, 0 impls, 3 clqs
# (round 2, fast)       393 del vars, 1086 del conss, 0 add conss, 381 chg bounds, 123 chg sides, 119 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 3, fast)       394 del vars, 1092 del conss, 0 add conss, 383 chg bounds, 123 chg sides, 119 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# presolving (4 rounds: 4 fast, 1 medium, 1 exhaustive):
#  395 deleted vars, 1092 deleted constraints, 0 added constraints, 383 tightened bounds, 0 added holes, 123 changed sides, 119 changed coefficients
#  0 implications, 0 cliques
# transformed 1/1 original solutions to the transformed problem space
# Presolving Time: 0.00
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 0.00
# Solving Nodes      : 0
# Primal Bound       : +6.50000000000000e+01 (1 solutions)
# Dual Bound         : +6.50000000000000e+01
# Gap                : 0.00 %
#
# <--------------------------------------------------------------------->
#
# Results for smt_7_6.dat:
# 	optimization_time: 0.009670643
# 	objective_value: 65.0
# 	proved_optimality: true
# 	timeout: false
#
# <--------------------------------------------------------------------->
# Running smt_7_10.dat
# presolving:
# (round 1, fast)       332 del vars, 669 del conss, 0 add conss, 327 chg bounds, 183 chg sides, 183 chg coeffs, 0 upgd conss, 0 impls, 6 clqs
# (round 2, fast)       334 del vars, 965 del conss, 0 add conss, 327 chg bounds, 183 chg sides, 183 chg coeffs, 0 upgd conss, 0 impls, 8 clqs
# (round 3, fast)       334 del vars, 965 del conss, 0 add conss, 328 chg bounds, 183 chg sides, 183 chg coeffs, 0 upgd conss, 0 impls, 8 clqs
#    (0.0s) running MILP presolver
#    (0.0s) MILP presolver (8 rounds): 10 aggregations, 16 fixings, 0 bound changes
# (round 4, medium)     360 del vars, 1092 del conss, 85 add conss, 328 chg bounds, 183 chg sides, 183 chg coeffs, 0 upgd conss, 0 impls, 7 clqs
# (round 5, exhaustive) 360 del vars, 1097 del conss, 85 add conss, 328 chg bounds, 188 chg sides, 183 chg coeffs, 0 upgd conss, 1 impls, 30 clqs
# (round 6, exhaustive) 360 del vars, 1097 del conss, 85 add conss, 328 chg bounds, 188 chg sides, 183 chg coeffs, 58 upgd conss, 1 impls, 30 clqs
#    (0.0s) probing cycle finished: starting next cycle
# (round 7, exhaustive) 366 del vars, 1097 del conss, 85 add conss, 328 chg bounds, 188 chg sides, 183 chg coeffs, 58 upgd conss, 26 impls, 269 clqs
# (round 8, fast)       366 del vars, 1100 del conss, 85 add conss, 328 chg bounds, 188 chg sides, 183 chg coeffs, 58 upgd conss, 26 impls, 269 clqs
#    (0.0s) running MILP presolver
#    (0.0s) MILP presolver (2 rounds): 0 aggregations, 0 fixings, 0 bound changes
# (round 9, medium)     366 del vars, 1102 del conss, 85 add conss, 328 chg bounds, 188 chg sides, 183 chg coeffs, 58 upgd conss, 26 impls, 269 clqs
# (round 10, exhaustive) 366 del vars, 1104 del conss, 85 add conss, 328 chg bounds, 188 chg sides, 183 chg coeffs, 58 upgd conss, 26 impls, 269 clqs
# (round 11, exhaustive) 366 del vars, 1104 del conss, 85 add conss, 328 chg bounds, 188 chg sides, 183 chg coeffs, 59 upgd conss, 26 impls, 269 clqs
#    (0.0s) probing cycle finished: starting next cycle
#    (0.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (0.0s) no symmetry present
# presolving (12 rounds: 12 fast, 8 medium, 6 exhaustive):
#  366 deleted vars, 1104 deleted constraints, 85 added constraints, 328 tightened bounds, 0 added holes, 188 changed sides, 183 changed coefficients
#  26 implications, 269 cliques
# presolved problem has 27 variables (26 bin, 1 int, 0 impl, 0 cont) and 73 constraints
#      15 constraints of type <varbound>
#      24 constraints of type <setppc>
#      19 constraints of type <linear>
#      15 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# p 0.0s|     1 |     0 |     0 |     - |  clique|   0 |  27 |  73 |  73 |   0 |  0 |   0 |   0 | 0.000000e+00 | 8.600000e+01 |    Inf | unknown
# p 0.0s|     1 |     0 |     0 |     - |   locks|   0 |  27 |  73 |  73 |   0 |  0 |   0 |   0 | 0.000000e+00 | 8.500000e+01 |    Inf | unknown
# p 0.0s|     1 |     0 |     0 |     - | vbounds|   0 |  27 |  73 |  73 |   0 |  0 |   0 |   0 | 0.000000e+00 | 4.500000e+01 |    Inf | unknown
# p 0.0s|     1 |     0 |     0 |     - | vbounds|   0 |  27 |  76 |  73 |   0 |  0 |   5 |   0 | 0.000000e+00 | 4.300000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |     0 |     - |  3931k |   0 |  27 |   5 |  73 |   0 |  0 |   5 |   0 | 4.300000e+01 | 4.300000e+01 |   0.00%| unknown
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 0.00
# Solving Nodes      : 1
# Primal Bound       : +4.30000000000000e+01 (4 solutions)
# Dual Bound         : +4.30000000000000e+01
# Gap                : 0.00 %
#
# <--------------------------------------------------------------------->
#
# Results for smt_7_10.dat:
# 	optimization_time: 0.014697259
# 	objective_value: 43.0
# 	proved_optimality: true
# 	timeout: false
#
# <--------------------------------------------------------------------->
# Running smt_7_15.dat
# presolving:
# (round 1, fast)       292 del vars, 570 del conss, 0 add conss, 287 chg bounds, 253 chg sides, 253 chg coeffs, 0 upgd conss, 0 impls, 7 clqs
# (round 2, fast)       292 del vars, 865 del conss, 0 add conss, 287 chg bounds, 253 chg sides, 253 chg coeffs, 0 upgd conss, 0 impls, 7 clqs
# (round 3, fast)       292 del vars, 865 del conss, 0 add conss, 288 chg bounds, 253 chg sides, 253 chg coeffs, 0 upgd conss, 0 impls, 7 clqs
#    (0.0s) running MILP presolver
#    (0.0s) MILP presolver found nothing
# (round 4, exhaustive) 292 del vars, 865 del conss, 0 add conss, 288 chg bounds, 253 chg sides, 253 chg coeffs, 145 upgd conss, 0 impls, 7 clqs
#    (0.0s) probing cycle finished: starting next cycle
# (round 5, exhaustive) 300 del vars, 865 del conss, 0 add conss, 288 chg bounds, 253 chg sides, 253 chg coeffs, 145 upgd conss, 61 impls, 2319 clqs
# (round 6, fast)       300 del vars, 873 del conss, 0 add conss, 288 chg bounds, 253 chg sides, 253 chg coeffs, 145 upgd conss, 61 impls, 2319 clqs
# (round 7, exhaustive) 300 del vars, 881 del conss, 0 add conss, 288 chg bounds, 253 chg sides, 253 chg coeffs, 145 upgd conss, 61 impls, 2319 clqs
#    (0.0s) probing cycle finished: starting next cycle
#    (0.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (0.0s) no symmetry present
# presolving (8 rounds: 8 fast, 4 medium, 4 exhaustive):
#  300 deleted vars, 881 deleted constraints, 0 added constraints, 288 tightened bounds, 0 added holes, 253 changed sides, 253 changed coefficients
#  61 implications, 2558 cliques
# presolved problem has 93 variables (92 bin, 1 int, 0 impl, 0 cont) and 211 constraints
#      61 constraints of type <varbound>
#       7 constraints of type <setppc>
#      74 constraints of type <linear>
#      69 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# p 0.0s|     1 |     0 |     0 |     - |  clique|   0 |  93 | 211 | 211 |   0 |  0 |   0 |   0 | 0.000000e+00 | 5.100000e+01 |    Inf | unknown
# p 0.0s|     1 |     0 |     0 |     - | vbounds|   0 |  93 | 219 | 211 |   0 |  0 |  11 |   0 | 0.000000e+00 | 1.700000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |     8 |     - |  4824k |   0 |  93 | 218 | 211 |   0 |  0 |  14 |   0 | 0.000000e+00 | 1.700000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |     8 |     - |  4826k |   0 |  93 | 218 | 127 |   0 |  0 |  14 |   0 | 0.000000e+00 | 1.700000e+01 |    Inf | unknown
# * 0.0s|     1 |     0 |     8 |     - |    LP  |   0 |  93 | 217 | 127 |   0 |  0 |  14 |   0 | 0.000000e+00 | 1.000000e+00 |    Inf | unknown
#   0.0s|     1 |     0 |     8 |     - |  4864k |   0 |  93 | 217 | 127 |   0 |  1 |  14 |   0 | 1.000000e+00 | 1.000000e+00 |   0.00%| unknown
#   0.0s|     1 |     0 |     8 |     - |  4864k |   0 |  93 | 217 | 127 |   0 |  1 |  14 |   0 | 1.000000e+00 | 1.000000e+00 |   0.00%| unknown
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 0.00
# Solving Nodes      : 1
# Primal Bound       : +1.00000000000000e+00 (3 solutions)
# Dual Bound         : +1.00000000000000e+00
# Gap                : 0.00 %
#
# <--------------------------------------------------------------------->
#
# Results for smt_7_15.dat:
# 	optimization_time: 0.042915999
# 	objective_value: 1.0
# 	proved_optimality: true
# 	timeout: false
#
# <--------------------------------------------------------------------->
# Running smt_50_250.dat
# presolving:
# (round 1, fast)       122138 del vars, 213152 del conss, 0 add conss, 122090 chg bounds, 44158 chg sides, 44158 chg coeffs, 0 upgd conss, 0 impls, 50 clqs
# (round 2, fast)       122138 del vars, 363326 del conss, 0 add conss, 122090 chg bounds, 44158 chg sides, 44158 chg coeffs, 0 upgd conss, 0 impls, 50 clqs
#    (1.0s) running MILP presolver
#    (1.0s) MILP presolver found nothing
# (round 3, exhaustive) 122138 del vars, 363326 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 0 impls, 50 clqs
# (round 4, exhaustive) 122163 del vars, 363326 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 77185 clqs
# (round 5, fast)       122163 del vars, 363351 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 77185 clqs
# (round 6, exhaustive) 122163 del vars, 363376 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 77185 clqs
# (round 7, exhaustive) 122188 del vars, 363376 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76902 clqs
# (round 8, fast)       122188 del vars, 363401 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76902 clqs
# (round 9, exhaustive) 122188 del vars, 363426 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76902 clqs
# (round 10, exhaustive) 122213 del vars, 363426 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76610 clqs
# (round 11, fast)       122213 del vars, 363451 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76610 clqs
# (round 12, exhaustive) 122213 del vars, 363476 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76610 clqs
# (round 13, exhaustive) 122238 del vars, 363476 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76338 clqs
# (round 14, fast)       122238 del vars, 363501 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76338 clqs
# (round 15, exhaustive) 122238 del vars, 363526 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76338 clqs
# (round 16, exhaustive) 122263 del vars, 363526 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76076 clqs
# (round 17, fast)       122263 del vars, 363551 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76076 clqs
# (round 18, exhaustive) 122263 del vars, 363576 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 76076 clqs
# (round 19, exhaustive) 122288 del vars, 363576 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 169753 clqs
# (round 20, fast)       122288 del vars, 363601 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 169753 clqs
# (round 21, exhaustive) 122288 del vars, 363626 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 169753 clqs
# (round 22, exhaustive) 122313 del vars, 363626 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 169087 clqs
# (round 23, fast)       122313 del vars, 363651 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 169087 clqs
# (round 24, exhaustive) 122313 del vars, 363676 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 169087 clqs
# (round 25, exhaustive) 122338 del vars, 363676 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 168418 clqs
# (round 26, fast)       122338 del vars, 363701 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 168418 clqs
# (round 27, exhaustive) 122338 del vars, 363726 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 168418 clqs
# (round 28, exhaustive) 122363 del vars, 363726 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 214996 clqs
# (round 29, fast)       122363 del vars, 363751 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 214996 clqs
# (round 30, exhaustive) 122363 del vars, 363776 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 214996 clqs
#    (3.0s) probing: 1000/5362 (18.6%) - 0 fixings, 232 aggregations, 401820 implications, 0 bound changes
#    (4.0s) probing: 1865/5362 (34.8%) - 0 fixings, 232 aggregations, 763340 implications, 0 bound changes
#    (4.0s) probing aborted: 1000/1000 successive useless probings
# (round 31, exhaustive) 122370 del vars, 363776 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 622426 clqs
# (round 32, exhaustive) 122370 del vars, 363790 del conss, 0 add conss, 122091 chg bounds, 44158 chg sides, 44158 chg coeffs, 9346 upgd conss, 4416 impls, 622426 clqs
#    (5.0s) probing: 1965/5362 (36.6%) - 0 fixings, 232 aggregations, 798537 implications, 0 bound changes
#    (5.0s) probing aborted: 1000/1000 successive useless probings
#    (5.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (5.0s) no symmetry present
# presolving (33 rounds: 33 fast, 22 medium, 22 exhaustive):
#  122370 deleted vars, 363790 deleted constraints, 0 added constraints, 122091 tightened bounds, 0 added holes, 44158 changed sides, 44158 changed coefficients
#  4416 implications, 657623 cliques
# presolved problem has 5131 variables (5130 bin, 1 int, 0 impl, 0 cont) and 13810 constraints
#    4416 constraints of type <varbound>
#      50 constraints of type <setppc>
#    4696 constraints of type <linear>
#    4648 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 5.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# p 5.0s|     1 |     0 |    25 |     - | vbounds|   0 |5131 |  13k|  13k|   0 |  0 |  25 |   0 | 0.000000e+00 | 7.639000e+03 |    Inf | unknown
#   5.0s|     1 |     0 |    46 |     - |   693M |   0 |5131 |  13k|  13k|   0 |  0 |  34 |   0 | 0.000000e+00 | 7.639000e+03 |    Inf | unknown
#   7.0s|     1 |     0 |    56 |     - |   695M |   0 |5131 |  13k|  13k|   4 |  1 |  34 |   0 | 0.000000e+00 | 7.639000e+03 |    Inf | unknown
#   7.0s|     1 |     0 |    76 |     - |   696M |   0 |5131 |  13k|  13k|   9 |  2 |  34 |   0 | 0.000000e+00 | 7.639000e+03 |    Inf | unknown
#   7.0s|     1 |     0 |    88 |     - |   698M |   0 |5131 |  13k|  13k|  14 |  3 |  34 |   0 | 0.000000e+00 | 7.639000e+03 |    Inf | unknown
#   7.0s|     1 |     0 |   125 |     - |   699M |   0 |5131 |  13k|  13k|  21 |  4 |  34 |   0 | 0.000000e+00 | 7.639000e+03 |    Inf | unknown
#   7.0s|     1 |     0 |   164 |     - |   701M |   0 |5131 |  13k|  13k|  33 |  5 |  34 |   0 | 0.000000e+00 | 7.639000e+03 |    Inf | unknown
#   8.0s|     1 |     0 |   195 |     - |   703M |   0 |5131 |  13k|  13k|  38 |  6 |  34 |   0 | 0.000000e+00 | 7.639000e+03 |    Inf | unknown
#   8.0s|     1 |     0 |   217 |     - |   705M |   0 |5131 |  13k|  13k|  42 |  7 |  34 |   0 | 0.000000e+00 | 7.639000e+03 |    Inf | unknown
# r 8.0s|     1 |     0 |   217 |     - |shifting|   0 |5131 |  13k|  13k|  42 |  7 |  34 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
#   8.0s|     1 |     0 |   251 |     - |   708M |   0 |5131 |  13k|  13k|  50 |  8 |  34 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
#   8.0s|     1 |     0 |   251 |     - |   710M |   0 |5131 |  13k|  13k|  50 |  8 |  34 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
#   8.0s|     1 |     0 |   251 |     - |   710M |   0 |5131 |  13k|  12k|  50 |  8 |  34 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
#   8.0s|     1 |     0 |   300 |     - |   712M |   0 |5131 |  13k|  12k|  59 |  9 |  34 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
#   9.0s|     1 |     0 |   340 |     - |   717M |   0 |5131 |  13k|  12k|  65 | 10 |  34 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   9.0s|     1 |     0 |   407 |     - |   719M |   0 |5131 |  13k|  12k|  72 | 11 |  34 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
# (run 1, node 1) restarting after 645 global fixings of integer variables
#
# (restart) converted 71 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       645 del vars, 2 del conss, 0 add conss, 0 chg bounds, 2 chg sides, 645 chg coeffs, 0 upgd conss, 4416 impls, 506619 clqs
#    (9.0s) running MILP presolver
#    (10.0s) MILP presolver (2 rounds): 0 aggregations, 0 fixings, 1 bound changes
# (round 2, exhaustive) 645 del vars, 3 del conss, 0 add conss, 1 chg bounds, 2 chg sides, 645 chg coeffs, 61 upgd conss, 4416 impls, 506619 clqs
# presolving (3 rounds: 3 fast, 2 medium, 2 exhaustive):
#  645 deleted vars, 13 deleted constraints, 0 added constraints, 1 tightened bounds, 0 added holes, 2 changed sides, 695 changed coefficients
#  4416 implications, 506619 cliques
# presolved problem has 4486 variables (4485 bin, 1 int, 0 impl, 0 cont) and 12611 constraints
#    3771 constraints of type <varbound>
#      10 constraints of type <knapsack>
#      64 constraints of type <setppc>
#    4061 constraints of type <linear>
#    4705 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 6.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  10.0s|     1 |     0 |  1729 |     - |   722M |   0 |4486 |  12k|  12k|   0 |  0 |  36 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
#  11.0s|     1 |     0 |  1765 |     - |   724M |   0 |4486 |  12k|  12k|  16 |  1 |  36 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
#  11.0s|     1 |     0 |  1824 |     - |   725M |   0 |4486 |  12k|  12k|  26 |  2 |  36 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
#  12.0s|     1 |     0 |  1848 |     - |   726M |   0 |4486 |  12k|  12k|  30 |  3 |  36 |   0 | 0.000000e+00 | 6.346000e+03 |    Inf | unknown
# r12.0s|     1 |     0 |  1848 |     - |shifting|   0 |4486 |  12k|  12k|  30 |  3 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  12.0s|     1 |     0 |  1904 |     - |   728M |   0 |4486 |  12k|  12k|  36 |  4 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  12.0s|     1 |     0 |  1904 |     - |   728M |   0 |4486 |  12k|  12k|  36 |  4 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  12.0s|     1 |     0 |  1904 |     - |   728M |   0 |4486 |  12k|  12k|  36 |  4 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  12.0s|     1 |     0 |  1945 |     - |   730M |   0 |4486 |  12k|  12k|  42 |  5 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  12.0s|     1 |     0 |  1991 |     - |   734M |   0 |4486 |  12k|  12k|  48 |  6 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  13.0s|     1 |     0 |  2021 |     - |   735M |   0 |4486 |  12k|  12k|  57 |  7 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  13.0s|     1 |     0 |  2075 |     - |   738M |   0 |4486 |  12k|  12k|  69 |  8 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  13.0s|     1 |     0 |  2119 |     - |   739M |   0 |4486 |  12k|  12k|  75 |  9 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  13.0s|     1 |     0 |  2119 |     - |   739M |   0 |4486 |  12k|  12k|  75 |  9 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  14.0s|     1 |     0 |  2157 |     - |   741M |   0 |4486 |  12k|  12k|  83 | 10 |  36 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  14.0s|     1 |     0 |  2249 |     - |   745M |   0 |4486 |  12k|  12k|  93 | 11 |  37 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  14.0s|     1 |     0 |  2249 |     - |   745M |   0 |4486 |  12k|  12k|  93 | 11 |  37 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  14.0s|     1 |     0 |  2296 |     - |   747M |   0 |4486 |  12k|  12k| 100 | 12 |  37 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  15.0s|     1 |     0 |  2369 |     - |   750M |   0 |4486 |  12k|  12k| 106 | 13 |  38 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  15.0s|     1 |     0 |  2428 |     - |   751M |   0 |4486 |  12k|  12k| 113 | 14 |  38 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  15.0s|     1 |     0 |  2490 |     - |   753M |   0 |4486 |  12k|  12k| 119 | 15 |  38 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  15.0s|     1 |     0 |  2542 |     - |   756M |   0 |4486 |  12k|  12k| 126 | 16 |  38 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  16.0s|     1 |     0 |  2593 |     - |   760M |   0 |4486 |  12k|  12k| 131 | 17 |  38 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  16.0s|     1 |     0 |  2611 |     - |   762M |   0 |4486 |  12k|  12k| 134 | 18 |  38 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  16.0s|     1 |     0 |  2652 |     - |   765M |   0 |4486 |  12k|  12k| 137 | 19 |  38 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  17.0s|     1 |     0 |  2687 |     - |   769M |   0 |4486 |  12k|  12k| 140 | 20 |  38 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  17.0s|     1 |     0 |  2694 |     - |   769M |   0 |4486 |  12k|  12k| 142 | 21 |  40 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  17.0s|     1 |     0 |  2696 |     - |   769M |   0 |4486 |  12k|  12k| 143 | 22 |  40 |   0 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
#  18.0s|     1 |     2 |  3907 |     - |   769M |   0 |4486 |  12k|  12k| 143 | 22 |  44 |  38 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
# (run 2, node 1) restarting after 274 global fixings of integer variables
#
# (restart) converted 69 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       274 del vars, 0 del conss, 0 add conss, 0 chg bounds, 2 chg sides, 309 chg coeffs, 0 upgd conss, 4416 impls, 455244 clqs
# (round 2, exhaustive) 274 del vars, 1 del conss, 0 add conss, 0 chg bounds, 2 chg sides, 319 chg coeffs, 62 upgd conss, 4416 impls, 455244 clqs
# presolving (3 rounds: 3 fast, 2 medium, 2 exhaustive):
#  274 deleted vars, 8 deleted constraints, 0 added constraints, 0 tightened bounds, 0 added holes, 3 changed sides, 390 changed coefficients
#  4416 implications, 455244 cliques
# presolved problem has 4212 variables (4211 bin, 1 int, 0 impl, 0 cont) and 12130 constraints
#    3497 constraints of type <varbound>
#      32 constraints of type <knapsack>
#      66 constraints of type <setppc>
#    3794 constraints of type <linear>
#    4741 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 6.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  18.0s|     1 |     0 |  3967 |     - |   763M |   0 |4212 |  12k|  12k|   0 |  0 |  44 |  38 | 0.000000e+00 | 5.593000e+03 |    Inf | unknown
# r18.0s|     1 |     0 |  3967 |     - |shifting|   0 |4212 |  12k|  12k|   0 |  0 |  44 |  38 | 0.000000e+00 | 1.806000e+03 |    Inf | unknown
#  19.0s|     1 |     0 |  4030 |     - |   765M |   0 |4212 |  12k|  12k|  10 |  1 |  44 |  38 | 0.000000e+00 | 1.806000e+03 |    Inf | unknown
# i19.0s|     1 |     0 |  4030 |     - |  oneopt|   0 |4212 |  12k|  12k|  10 |  1 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  19.0s|     1 |     0 |  4062 |     - |   769M |   0 |4212 |  12k|  12k|  10 |  1 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  20.0s|     1 |     0 |  4062 |     - |   769M |   0 |4212 |  12k|  12k|  10 |  1 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  20.0s|     1 |     0 |  4062 |     - |   768M |   0 |4212 |  12k|7673 |  10 |  1 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  20.0s|     1 |     0 |  4075 |     - |   769M |   0 |4212 |  12k|7669 |  16 |  2 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  20.0s|     1 |     0 |  4101 |     - |   770M |   0 |4212 |  12k|7675 |  22 |  3 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  20.0s|     1 |     0 |  4121 |     - |   771M |   0 |4212 |  12k|7683 |  30 |  4 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  20.0s|     1 |     0 |  4140 |     - |   772M |   0 |4212 |  12k|7688 |  35 |  5 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  20.0s|     1 |     0 |  4149 |     - |   772M |   0 |4212 |  12k|7694 |  41 |  6 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  21.0s|     1 |     0 |  4192 |     - |   773M |   0 |4212 |  12k|7698 |  45 |  7 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  21.0s|     1 |     0 |  4192 |     - |   773M |   0 |4212 |  12k|7695 |  45 |  7 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  21.0s|     1 |     0 |  4240 |     - |   775M |   0 |4212 |  12k|7700 |  50 |  8 |  44 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  21.0s|     1 |     0 |  4295 |     - |   776M |   0 |4212 |  12k|7711 |  61 |  9 |  45 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  21.0s|     1 |     0 |  4355 |     - |   777M |   0 |4212 |  12k|7718 |  68 | 10 |  46 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  21.0s|     1 |     0 |  4414 |     - |   780M |   0 |4212 |  12k|7594 |  75 | 11 |  47 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  21.0s|     1 |     0 |  4414 |     - |   780M |   0 |4212 |  12k|7592 |  75 | 11 |  48 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  22.0s|     1 |     0 |  4475 |     - |   781M |   0 |4212 |  12k|7602 |  85 | 12 |  48 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
#  22.0s|     1 |     0 |  4475 |     - |   781M |   0 |4212 |7675 |7602 |  85 | 12 |  48 |  38 | 0.000000e+00 | 1.577000e+03 |    Inf | unknown
# *23.0s|     1 |     0 |  4475 |     - |    LP  |   0 |4212 |7675 |7602 |  85 | 12 |  48 |  38 | 0.000000e+00 | 1.349000e+03 |    Inf | unknown
#  23.0s|     1 |     0 |  4559 |     - |   781M |   0 |4212 |7636 |6477 | 104 | 13 |  48 |  38 | 0.000000e+00 | 1.349000e+03 |    Inf | unknown
# i23.0s|     1 |     0 |  4559 |     - |  oneopt|   0 |4212 |7636 |6477 | 104 | 13 |  48 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  23.0s|     1 |     0 |  4614 |     - |   786M |   0 |4212 |7278 |6485 | 112 | 14 |  48 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  23.0s|     1 |     0 |  4614 |     - |   786M |   0 |4212 |7279 |6391 | 112 | 14 |  49 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  23.0s|     1 |     0 |  4652 |     - |   786M |   0 |4212 |7225 |6371 | 123 | 15 |  49 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  23.0s|     1 |     0 |  4705 |     - |   788M |   0 |4212 |7215 |6382 | 134 | 16 |  49 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  23.0s|     1 |     0 |  4747 |     - |   791M |   0 |4212 |7215 |6390 | 142 | 17 |  50 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  23.0s|     1 |     0 |  4814 |     - |   794M |   0 |4212 |7193 |6404 | 156 | 18 |  51 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  24.0s|     1 |     0 |  4851 |     - |   795M |   0 |4212 |7191 |6414 | 166 | 19 |  51 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  24.0s|     1 |     0 |  4879 |     - |   797M |   0 |4212 |7190 |6422 | 174 | 20 |  51 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  24.0s|     1 |     0 |  4916 |     - |   797M |   0 |4212 |7184 |6389 | 180 | 21 |  51 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  24.0s|     1 |     0 |  4921 |     - |   797M |   0 |4212 |7180 |6390 | 181 | 22 |  51 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  24.0s|     1 |     0 |  4925 |     - |   797M |   0 |4212 |7180 |6391 | 182 | 23 |  52 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  24.0s|     1 |     0 |  4927 |     - |   797M |   0 |4212 |7180 |6394 | 185 | 24 |  53 |  38 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  24.0s|     1 |     0 |  5271 |     - |   798M |   0 |4212 |6495 |6394 | 185 | 24 |  62 |  54 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  24.0s|     1 |     0 |  5305 |     - |   798M |   0 |4212 |6490 |6395 | 186 | 25 |  63 |  54 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
#  24.0s|     1 |     2 |  5327 |     - |   798M |   0 |4212 |6490 |6395 | 186 | 26 |  63 |  64 | 0.000000e+00 | 1.282000e+03 |    Inf | unknown
# *25.0s|     6 |     5 |  5432 | 422.3 |    LP  |   5 |4212 |6490 |6299 | 186 |  0 |  63 |  64 | 0.000000e+00 | 1.086000e+03 |    Inf | unknown
# i25.0s|     6 |     5 |  5444 | 424.0 |  oneopt|   5 |4212 |6490 |6299 | 186 |  1 |  63 |  64 | 0.000000e+00 | 1.061000e+03 |    Inf | unknown
# *25.0s|    22 |     9 |  5841 | 146.3 |    LP  |  13 |4212 |6509 |6301 | 238 |  0 |  92 |  76 | 0.000000e+00 | 7.650000e+02 |    Inf |   0.21%
# i25.0s|    22 |    11 |  5856 | 147.0 |  oneopt|  13 |4212 |6509 |6301 | 238 |  2 |  92 |  76 | 0.000000e+00 | 6.750000e+02 |    Inf |   0.21%
# *26.0s|    41 |    16 |  6470 |  95.1 |    LP  |  13 |4212 |6059 |6299 | 274 |  0 | 105 |  76 | 0.000000e+00 | 5.010000e+02 |    Inf |  12.85%
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 27.00
# Solving Nodes      : 96 (total of 98 nodes in 3 runs)
# Primal Bound       : +5.01000000000000e+02 (12 solutions)
# Dual Bound         : +5.01000000000000e+02
# Gap                : 0.00 %
#
# <--------------------------------------------------------------------->
# Results for smt_50_250.dat:
# 	optimization_time: 29.417423863
# 	objective_value: 501.0
# 	proved_optimality: true
# 	timeout: false
#
# <--------------------------------------------------------------------->
# Running smt_50_500.dat
# presolving:
# (round 1, fast)       107864 del vars, 165217 del conss, 0 add conss, 107816 chg bounds, 78338 chg sides, 78338 chg coeffs, 0 upgd conss, 0 impls, 50 clqs
# (round 2, fast)       107864 del vars, 322371 del conss, 0 add conss, 107816 chg bounds, 78338 chg sides, 78338 chg coeffs, 0 upgd conss, 0 impls, 50 clqs
#    (1.0s) running MILP presolver
#    (2.0s) MILP presolver found nothing
# (round 3, exhaustive) 107864 del vars, 322371 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 0 impls, 50 clqs
# (round 4, exhaustive) 107889 del vars, 322371 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 435425 clqs
# (round 5, exhaustive) 107889 del vars, 322421 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 435425 clqs
# (round 6, exhaustive) 107914 del vars, 322421 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 435709 clqs
# (round 7, exhaustive) 107914 del vars, 322471 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 435709 clqs
# (round 8, exhaustive) 107939 del vars, 322471 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 435310 clqs
# (round 9, exhaustive) 107939 del vars, 322521 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 435310 clqs
# (round 10, exhaustive) 107964 del vars, 322521 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 434901 clqs
# (round 11, exhaustive) 107964 del vars, 322571 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 434901 clqs
# (round 12, exhaustive) 107989 del vars, 322571 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 434495 clqs
# (round 13, exhaustive) 107989 del vars, 322621 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 434495 clqs
# (round 14, exhaustive) 108014 del vars, 322621 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 434110 clqs
# (round 15, exhaustive) 108014 del vars, 322671 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 434110 clqs
# (round 16, exhaustive) 108039 del vars, 322671 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 433711 clqs
# (round 17, exhaustive) 108039 del vars, 322721 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 433711 clqs
# (round 18, exhaustive) 108064 del vars, 322721 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 962889 clqs
# (round 19, exhaustive) 108064 del vars, 322771 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 962889 clqs
# (round 20, exhaustive) 108089 del vars, 322771 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 961891 clqs
# (round 21, exhaustive) 108089 del vars, 322821 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 961891 clqs
# (round 22, exhaustive) 108114 del vars, 322821 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 962274 clqs
# (round 23, exhaustive) 108114 del vars, 322871 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 962274 clqs
# (round 24, exhaustive) 108139 del vars, 322871 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 961211 clqs
# (round 25, exhaustive) 108139 del vars, 322921 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 961211 clqs
#    (14.0s) probing: 1000/19636 (5.1%) - 0 fixings, 291 aggregations, 1674074 implications, 0 bound changes
#    (21.0s) probing: 1971/19636 (10.0%) - 0 fixings, 291 aggregations, 3464577 implications, 0 bound changes
#    (21.0s) probing aborted: 1000/1000 successive useless probings
# (round 26, exhaustive) 108155 del vars, 322921 del conss, 0 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 971802 clqs
#    (22.0s) probing: 2000/19636 (10.2%) - 0 fixings, 291 aggregations, 3518593 implications, 0 bound changes
#    (23.0s) probing: 2071/19636 (10.5%) - 0 fixings, 291 aggregations, 3659446 implications, 0 bound changes
#    (23.0s) probing aborted: 1000/1000 successive useless probings
#    (23.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (24.0s) symmetry computation finished: 164 generators found (max: 1500, log10 of symmetry group size: 49.4)
# (round 27, exhaustive) 108155 del vars, 322953 del conss, 164 add conss, 107817 chg bounds, 78338 chg sides, 78338 chg coeffs, 36500 upgd conss, 17769 impls, 1009265 clqs
# presolving (28 rounds: 28 fast, 26 medium, 26 exhaustive):
#  108155 deleted vars, 322953 deleted constraints, 164 added constraints, 107817 tightened bounds, 0 added holes, 78338 changed sides, 78338 changed coefficients
#  17769 implications, 1009265 cliques
# presolved problem has 19346 variables (19345 bin, 1 int, 0 impl, 0 cont) and 54811 constraints
#   17769 constraints of type <varbound>
#      50 constraints of type <setppc>
#   18438 constraints of type <linear>
#     164 constraints of type <orbitope>
#   18390 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 24.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# p24.0s|     1 |     0 |     0 |     - |   locks|   0 |  19k|  54k|  54k|   0 |  0 |   0 |   0 | 0.000000e+00 | 8.068000e+03 |    Inf | unknown
# p25.0s|     1 |     0 |     0 |     - | vbounds|   0 |  19k|  54k|  54k|   0 |  0 |   0 |   0 | 0.000000e+00 | 8.049000e+03 |    Inf | unknown
# p25.0s|     1 |     0 |    41 |     - | vbounds|   0 |  19k|  54k|  54k|   0 |  0 |  13 |   0 | 0.000000e+00 | 1.060000e+03 |    Inf | unknown
#  26.0s|     1 |     0 |    48 |     - |   993M |   0 |  19k|  26k|  54k|   0 |  0 |  13 |   0 | 0.000000e+00 | 1.060000e+03 |    Inf | unknown
#  27.0s|     1 |     0 |    52 |     - |  1003M |   0 |  19k|  26k|  54k|   5 |  1 |  13 |   0 | 0.000000e+00 | 1.060000e+03 |    Inf | unknown
#  27.0s|     1 |     0 |    56 |     - |  1009M |   0 |  19k|  26k|  54k|  10 |  2 |  13 |   0 | 0.000000e+00 | 1.060000e+03 |    Inf | unknown
#  28.0s|     1 |     0 |    61 |     - |  1015M |   0 |  19k|  26k|  54k|  13 |  3 |  13 |   0 | 0.000000e+00 | 1.060000e+03 |    Inf | unknown
#  28.0s|     1 |     0 |    65 |     - |  1020M |   0 |  19k|  26k|  54k|  17 |  4 |  13 |   0 | 0.000000e+00 | 1.060000e+03 |    Inf | unknown
#  28.0s|     1 |     0 |    69 |     - |  1026M |   0 |  19k|  26k|  54k|  21 |  5 |  13 |   0 | 0.000000e+00 | 1.060000e+03 |    Inf | unknown
#  28.0s|     1 |     0 |    73 |     - |  1032M |   0 |  19k|  26k|  54k|  26 |  6 |  13 |   0 | 0.000000e+00 | 1.060000e+03 |    Inf | unknown
#  28.0s|     1 |     0 |    84 |     - |  1038M |   0 |  19k|  26k|  54k|  31 |  7 |  14 |   0 | 0.000000e+00 | 1.060000e+03 |    Inf | unknown
# r28.0s|     1 |     0 |    84 |     - |shifting|   0 |  19k|  26k|  54k|  31 |  7 |  14 |   0 | 0.000000e+00 | 6.400000e+02 |    Inf | unknown
#  29.0s|     1 |     0 |    89 |     - |  1046M |   0 |  19k|  26k|  54k|  33 |  8 |  14 |   0 | 0.000000e+00 | 6.400000e+02 |    Inf | unknown
#  29.0s|     1 |     0 |    89 |     - |  1048M |   0 |  19k|  26k|  26k|  33 |  8 |  14 |   0 | 0.000000e+00 | 6.400000e+02 |    Inf | unknown
#  29.0s|     1 |     0 |    89 |     - |  1048M |   0 |  19k|  26k|  23k|  33 |  8 |  14 |   0 | 0.000000e+00 | 6.400000e+02 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  29.0s|     1 |     0 |    95 |     - |  1050M |   0 |  19k|  26k|  23k|  34 |  9 |  14 |   0 | 0.000000e+00 | 6.400000e+02 |    Inf | unknown
#  29.0s|     1 |     0 |   101 |     - |  1052M |   0 |  19k|  26k|  23k|  36 | 10 |  14 |   0 | 0.000000e+00 | 6.400000e+02 |    Inf | unknown
#  29.0s|     1 |     0 |   102 |     - |  1055M |   0 |  19k|  26k|  23k|  37 | 11 |  14 |   0 | 0.000000e+00 | 6.400000e+02 |    Inf | unknown
#  29.0s|     1 |     0 |   106 |     - |  1058M |   0 |  19k|  26k|  23k|  40 | 12 |  14 |   0 | 0.000000e+00 | 6.400000e+02 |    Inf | unknown
# d30.0s|     1 |     0 |   683 |     - |conflict|   0 |  19k|  23k|  23k|   0 | 12 |  15 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
# (run 1, node 1) restarting after 15582 global fixings of integer variables
#
# (restart) converted 40 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       15798 del vars, 432 del conss, 0 add conss, 217 chg bounds, 216 chg sides, 15798 chg coeffs, 0 upgd conss, 17769 impls, 143999 clqs
# (round 2, exhaustive) 15798 del vars, 434 del conss, 0 add conss, 217 chg bounds, 218 chg sides, 15798 chg coeffs, 38 upgd conss, 17769 impls, 143999 clqs
# presolving (3 rounds: 3 fast, 2 medium, 2 exhaustive):
#  15798 deleted vars, 449 deleted constraints, 0 added constraints, 217 tightened bounds, 0 added holes, 218 changed sides, 15998 changed coefficients
#  17769 implications, 144000 cliques
# presolved problem has 3548 variables (3547 bin, 1 int, 0 impl, 0 cont) and 23254 constraints
#    1971 constraints of type <varbound>
#       3 constraints of type <knapsack>
#      53 constraints of type <setppc>
#    2640 constraints of type <linear>
#     164 constraints of type <orbitope>
#   18423 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 24.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  31.0s|     1 |     0 |   761 |     - |  1052M |   0 |3548 |  23k|  23k|   0 |  0 |  15 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  31.0s|     1 |     0 |   767 |     - |  1055M |   0 |3548 |  23k|  23k|   5 |  1 |  15 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  32.0s|     1 |     0 |   781 |     - |  1058M |   0 |3548 |  23k|  23k|   8 |  2 |  15 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  32.0s|     1 |     0 |   810 |     - |  1061M |   0 |3548 |  23k|  23k|  14 |  3 |  15 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  32.0s|     1 |     0 |   831 |     - |  1064M |   0 |3548 |  23k|  23k|  19 |  4 |  15 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  32.0s|     1 |     0 |   848 |     - |  1066M |   0 |3548 |  23k|  23k|  23 |  5 |  16 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  33.0s|     1 |     0 |   852 |     - |  1069M |   0 |3548 |  23k|  23k|  25 |  6 |  16 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  33.0s|     1 |     0 |   853 |     - |  1071M |   0 |3548 |  23k|  23k|  28 |  7 |  16 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  33.0s|     1 |     0 |   859 |     - |  1074M |   0 |3548 |  23k|  23k|  31 |  8 |  16 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  33.0s|     1 |     0 |   871 |     - |  1077M |   0 |3548 |  23k|  23k|  35 |  9 |  16 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  34.0s|     1 |     0 |   892 |     - |  1082M |   0 |3548 |  23k|  23k|  40 | 10 |  16 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
#  34.0s|     1 |     0 |   910 |     - |  1085M |   0 |3548 |  23k|  23k|  46 | 11 |  16 |   0 | 0.000000e+00 | 5.660000e+02 |    Inf | unknown
# d34.0s|     1 |     0 |  1147 |     - |conflict|   0 |3548 |  23k|  23k|   0 | 11 |  16 |   0 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  34.0s|     1 |     0 |  1160 |     - |  1086M |   0 |3548 |  22k|  23k|  46 | 11 |  16 |   0 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  34.0s|     1 |     0 |  1168 |     - |  1089M |   0 |3548 |  22k|  23k|  49 | 12 |  16 |   0 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  34.0s|     1 |     0 |  1168 |     - |  1089M |   0 |3548 |  22k|  23k|  49 | 13 |  16 |   9 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  34.0s|     1 |     0 |  1189 |     - |  1091M |   0 |3548 |  22k|  23k|  57 | 14 |  16 |   9 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  34.0s|     1 |     0 |  1201 |     - |  1091M |   0 |3548 |  22k|  23k|  57 | 15 |  17 |  17 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  35.0s|     1 |     0 |  1211 |     - |  1094M |   0 |3548 |  22k|  23k|  64 | 16 |  17 |  17 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  35.0s|     1 |     0 |  1213 |     - |  1094M |   0 |3548 |  22k|  23k|  64 | 17 |  17 |  19 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  35.0s|     1 |     0 |  1224 |     - |  1097M |   0 |3548 |  22k|  23k|  69 | 18 |  21 |  19 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  35.0s|     1 |     0 |  1244 |     - |  1097M |   0 |3548 |  22k|  23k|  69 | 19 |  22 |  32 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  35.0s|     1 |     0 |  1263 |     - |  1099M |   0 |3548 |  22k|  23k|  73 | 20 |  22 |  32 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  35.0s|     1 |     0 |  1274 |     - |  1099M |   0 |3548 |  22k|  23k|  75 | 21 |  22 |  32 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  35.0s|     1 |     0 |  1282 |     - |  1099M |   0 |3548 |  22k|  23k|  75 | 21 |  22 |  45 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  35.0s|     1 |     0 |  1296 |     - |  1101M |   0 |3548 |  22k|  23k|  79 | 22 |  22 |  45 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  35.0s|     1 |     0 |  1303 |     - |  1102M |   0 |3548 |  22k|  23k|  79 | 23 |  22 |  52 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  36.0s|     1 |     0 |  1317 |     - |  1104M |   0 |3548 |  22k|  23k|  84 | 24 |  22 |  52 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  36.0s|     1 |     0 |  1322 |     - |  1104M |   0 |3548 |  22k|  23k|  84 | 25 |  22 |  54 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  36.0s|     1 |     0 |  1343 |     - |  1104M |   0 |3548 |  22k|  23k|  91 | 26 |  22 |  54 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  36.0s|     1 |     0 |  1352 |     - |  1104M |   0 |3548 |  22k|  23k|  91 | 27 |  24 |  58 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  36.0s|     1 |     0 |  1358 |     - |  1106M |   0 |3548 |  22k|  23k|  94 | 28 |  24 |  58 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  36.0s|     1 |     0 |  1362 |     - |  1106M |   0 |3548 |  22k|  23k|  96 | 29 |  24 |  58 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  36.0s|     1 |     0 |  1363 |     - |  1107M |   0 |3548 |  22k|  23k|  96 | 29 |  24 |  63 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
#  36.0s|     1 |     2 |  1363 |     - |  1107M |   0 |3548 |  22k|  23k|  96 | 31 |  24 |  63 | 0.000000e+00 | 4.950000e+02 |    Inf | unknown
# (run 2, node 1) restarting after 285 global fixings of integer variables
#
# (restart) converted 67 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       286 del vars, 6 del conss, 0 add conss, 1 chg bounds, 2 chg sides, 285 chg coeffs, 0 upgd conss, 17769 impls, 128442 clqs
# ...
#  56.0s|     1 |     0 |  1549 |     - |  5113M |   0 |  24k|  84k|  83k|  29 |  6 |  17 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  56.0s|     1 |     0 |  1549 |     - |  5119M |   0 |  24k|  84k|  83k|  29 |  6 |  17 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  57.0s|     1 |     0 |  1549 |     - |  5119M |   0 |  24k|  84k|  75k|  29 |  6 |  17 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  58.0s|     1 |     0 |  1571 |     - |  5132M |   0 |  24k|  84k|  75k|  32 |  7 |  17 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  60.0s|     1 |     0 |  1612 |     - |  5145M |   0 |  24k|  84k|  75k|  37 |  8 |  17 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  62.0s|     1 |     0 |  1633 |     - |  5159M |   0 |  24k|  84k|  75k|  40 |  9 |  17 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  65.0s|     1 |     0 |  1671 |     - |  5173M |   0 |  24k|  84k|  75k|  42 | 10 |  17 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  67.0s|     1 |     0 |  1720 |     - |  5183M |   0 |  24k|  84k|  75k|  47 | 11 |  17 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
# (run 2, node 1) restarting after 4236 global fixings of integer variables
#
# (restart) converted 47 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       4236 del vars, 0 del conss, 0 add conss, 0 chg bounds, 0 chg sides, 4240 chg coeffs, 0 upgd conss, 37588 impls, 336113 clqs
# presolving (2 rounds: 2 fast, 1 medium, 1 exhaustive):
#  4236 deleted vars, 6 deleted constraints, 0 added constraints, 0 tightened bounds, 0 added holes, 0 changed sides, 4356 changed coefficients
#  37588 implications, 336113 cliques
# presolved problem has 20638 variables (20637 bin, 1 int, 0 impl, 0 cont) and 76171 constraints
#   16811 constraints of type <varbound>
#      25 constraints of type <knapsack>
#     110 constraints of type <setppc>
#   18795 constraints of type <linear>
#     933 constraints of type <orbitope>
#   39497 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 25.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  72.0s|     1 |     0 |  7841 |     - |  5123M |   0 |  20k|  76k|  75k|   0 |  0 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  76.0s|     1 |     0 |  7859 |     - |  5132M |   0 |  20k|  76k|  75k|   5 |  1 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  77.0s|     1 |     0 |  7866 |     - |  5140M |   0 |  20k|  76k|  75k|   6 |  2 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  78.0s|     1 |     0 |  7882 |     - |  5150M |   0 |  20k|  76k|  75k|  10 |  3 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  79.0s|     1 |     0 |  7923 |     - |  5158M |   0 |  20k|  76k|  75k|  16 |  4 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  81.0s|     1 |     0 |  7936 |     - |  5168M |   0 |  20k|  76k|  75k|  19 |  5 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  82.0s|     1 |     0 |  7950 |     - |  5181M |   0 |  20k|  76k|  75k|  25 |  6 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  83.0s|     1 |     0 |  7976 |     - |  5189M |   0 |  20k|  76k|  75k|  27 |  7 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  85.0s|     1 |     0 |  7999 |     - |  5198M |   0 |  20k|  76k|  75k|  39 |  8 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  87.0s|     1 |     0 |  8014 |     - |  5211M |   0 |  20k|  76k|  75k|  42 |  9 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  89.0s|     1 |     0 |  8098 |     - |  5223M |   0 |  20k|  76k|  75k|  49 | 10 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  91.0s|     1 |     0 |  8121 |     - |  5235M |   0 |  20k|  76k|  75k|  57 | 11 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  93.0s|     1 |     0 |  8177 |     - |  5246M |   0 |  20k|  76k|  75k|  63 | 12 |  19 |   0 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
#  95.0s|     1 |     2 |  8207 |     - |  5248M |   0 |  20k|  76k|  75k|  63 | 12 |  19 |  31 | 0.000000e+00 | 2.575000e+03 |    Inf | unknown
# r 114s|    62 |    57 | 22914 | 349.1 |shifting|  40 |  20k|  76k|  75k| 147 |  0 |  24 |  31 | 0.000000e+00 | 1.718000e+03 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   124s|   100 |    95 | 35398 | 341.4 |  5421M |  48 |  20k|  76k|  75k| 197 |  1 |  58 |  62 | 0.000000e+00 | 1.718000e+03 |    Inf | unknown
# d 134s|   133 |   128 | 38173 | 278.0 |distribu|  50 |  20k|  76k|  75k|   0 |  1 | 127 | 191 | 0.000000e+00 | 1.625000e+03 |    Inf | unknown
# d 135s|   139 |   134 | 39045 | 272.3 |linesear|  50 |  20k|  76k|  75k|   0 |  1 | 129 | 191 | 0.000000e+00 | 1.318000e+03 |    Inf | unknown
# d 149s|   177 |   168 | 43994 | 242.0 |conflict|  50 |  20k|  76k|  75k|   0 |  1 | 247 | 191 | 0.000000e+00 | 1.277000e+03 |    Inf | unknown
#   151s|   200 |   189 | 46983 | 229.2 |  5575M |  50 |  20k|  76k|  75k| 270 |  1 | 257 | 191 | 0.000000e+00 | 1.277000e+03 |    Inf | unknown
# d 153s|   223 |   208 | 49434 | 216.6 |conflict|  50 |  20k|  76k|  75k|   0 |  1 | 318 | 191 | 0.000000e+00 | 1.207000e+03 |    Inf | unknown
# d 155s|   248 |   231 | 52080 | 205.5 |linesear|  50 |  20k|  76k|  75k|   0 |  1 | 366 | 191 | 0.000000e+00 | 1.145000e+03 |    Inf | unknown
#   161s|   300 |   277 | 62938 | 206.0 |  5580M |  50 |  20k|  76k|  75k| 281 |  1 | 522 | 191 | 0.000000e+00 | 1.145000e+03 |    Inf | unknown
# d 169s|   374 |   299 | 67574 | 177.7 |linesear|  56 |  20k|  76k|  75k|   0 |  1 | 708 | 227 | 0.000000e+00 | 7.890000e+02 |    Inf | unknown
# d 171s|   391 |   302 | 68945 | 173.5 |conflict|  57 |  20k|  76k|  75k|   0 |  1 | 804 | 236 | 0.000000e+00 | 7.240000e+02 |    Inf | unknown
#   172s|   400 |   311 | 69215 | 170.3 |  5625M |  57 |  20k|  76k|  75k| 373 |  2 | 848 | 236 | 0.000000e+00 | 7.240000e+02 |    Inf | unknown
#   177s|   500 |   371 | 74067 | 146.0 |  5627M |  57 |  20k|  76k|  75k| 378 |  1 |1124 | 274 | 0.000000e+00 | 7.240000e+02 |    Inf | unknown
# d 180s|   573 |   396 | 76211 | 131.2 |linesear|  58 |  20k|  76k|  75k|   0 |  1 |1281 | 280 | 0.000000e+00 | 5.980000e+02 |    Inf | unknown
#   182s|   600 |   413 | 77272 | 127.0 |  5644M |  59 |  20k|  76k|  75k| 402 |  1 |1388 | 287 | 0.000000e+00 | 5.980000e+02 |    Inf | unknown
# * 195s|   680 |   448 | 83063 | 120.6 |    LP  |  59 |  20k|  76k|  75k| 426 |  1 |1716 | 333 | 0.000000e+00 | 5.770000e+02 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   200s|   700 |   464 | 84463 | 119.2 |  5679M |  59 |  20k|  64k|  75k| 458 |  6 |1781 | 333 | 0.000000e+00 | 5.770000e+02 |    Inf | unknown
# d 212s|   799 |   409 | 87389 | 108.1 |linesear|  59 |  20k|  64k|  75k|   0 |  1 |1981 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf |   2.21%
#   212s|   800 |   410 | 87406 | 108.0 |  5717M |  59 |  20k|  64k|  75k| 603 |  1 |1981 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf |   2.21%
# Restart triggered after 50 consecutive estimations that the remaining tree will be large
# (run 3, node 879) performing user restart
#
# (restart) converted 20 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       13614 del vars, 14581 del conss, 4 add conss, 0 chg bounds, 6 chg sides, 13635 chg coeffs, 0 upgd conss, 37588 impls, 111940 clqs
# (round 2, exhaustive) 13614 del vars, 14765 del conss, 5 add conss, 0 chg bounds, 7 chg sides, 22100 chg coeffs, 27 upgd conss, 37588 impls, 111943 clqs
# (round 3, exhaustive) 13616 del vars, 14884 del conss, 5 add conss, 0 chg bounds, 7 chg sides, 22211 chg coeffs, 27 upgd conss, 37588 impls, 111976 clqs
# presolving (4 rounds: 4 fast, 3 medium, 3 exhaustive):
#  13618 deleted vars, 14887 deleted constraints, 5 added constraints, 0 tightened bounds, 0 added holes, 7 changed sides, 22687 changed coefficients
#  37588 implications, 111952 cliques
# presolved problem has 7021 variables (7020 bin, 1 int, 0 impl, 0 cont) and 49564 constraints
#    3196 constraints of type <varbound>
#      46 constraints of type <knapsack>
#     123 constraints of type <setppc>
#    5173 constraints of type <linear>
#     933 constraints of type <orbitope>
#   40086 constraints of type <logicor>
#       7 constraints of type <bounddisjunction>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 28.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   238s|     1 |     0 | 88971 |     - |  5887M |   0 |7021 |  49k|  47k|   0 |  0 |2247 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   239s|     1 |     0 | 89027 |     - |  5893M |   0 |7021 |  49k|  47k|   2 |  1 |2248 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   239s|     1 |     0 | 89037 |     - |  5898M |   0 |7021 |  49k|  47k|   5 |  2 |2248 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   240s|     1 |     0 | 89040 |     - |  5903M |   0 |7021 |  49k|  47k|   7 |  3 |2248 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   241s|     1 |     0 | 89047 |     - |  5908M |   0 |7021 |  49k|  47k|   9 |  4 |2248 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   241s|     1 |     0 | 89056 |     - |  5913M |   0 |7021 |  49k|  47k|  11 |  5 |2249 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   242s|     1 |     0 | 89061 |     - |  5918M |   0 |7021 |  49k|  47k|  12 |  6 |2251 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   243s|     1 |     0 | 89071 |     - |  5923M |   0 |7021 |  49k|  47k|  13 |  7 |2252 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   244s|     1 |     0 | 89079 |     - |  5928M |   0 |7021 |  49k|  47k|  15 |  8 |2252 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   245s|     1 |     0 | 89084 |     - |  5934M |   0 |7021 |  49k|  47k|  17 |  9 |2252 | 333 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   246s|     1 |     0 | 89313 |     - |  5941M |   0 |7021 |  49k|  47k|  17 | 11 |2257 | 351 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   246s|     1 |     0 | 89327 |     - |  5941M |   0 |7021 |  49k|  47k|  20 | 12 |2258 | 351 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   247s|     1 |     0 | 89332 |     - |  5941M |   0 |7021 |  49k|  47k|  20 | 13 |2258 | 363 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   247s|     1 |     0 | 89338 |     - |  5946M |   0 |7021 |  49k|  47k|  21 | 14 |2258 | 363 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   247s|     1 |     0 | 89341 |     - |  5946M |   0 |7021 |  49k|  47k|  21 | 15 |2258 | 368 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   248s|     1 |     0 | 89344 |     - |  5953M |   0 |7021 |  49k|  47k|  22 | 16 |2258 | 368 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   248s|     1 |     0 | 89346 |     - |  5953M |   0 |7021 |  49k|  47k|  23 | 17 |2259 | 368 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   248s|     1 |     0 | 89350 |     - |  5953M |   0 |7021 |  49k|  47k|  23 | 17 |2259 | 372 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   248s|     1 |     0 | 89357 |     - |  5958M |   0 |7021 |  49k|  47k|  25 | 18 |2260 | 372 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   249s|     1 |     0 | 89361 |     - |  5958M |   0 |7021 |  49k|  47k|  25 | 19 |2260 | 377 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   249s|     1 |     0 | 89375 |     - |  5963M |   0 |7021 |  49k|  47k|  27 | 20 |2261 | 377 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   249s|     1 |     0 | 89382 |     - |  5963M |   0 |7021 |  49k|  47k|  27 | 21 |2261 | 382 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   250s|     1 |     0 | 89396 |     - |  5968M |   0 |7021 |  49k|  47k|  31 | 22 |2261 | 382 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   250s|     1 |     0 | 89398 |     - |  5968M |   0 |7021 |  49k|  47k|  31 | 23 |2262 | 389 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   250s|     1 |     0 | 89404 |     - |  5969M |   0 |7021 |  49k|  47k|  35 | 24 |2262 | 389 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   250s|     1 |     0 | 89407 |     - |  5970M |   0 |7021 |  49k|  47k|  35 | 25 |2263 | 391 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   251s|     1 |     0 | 89417 |     - |  5974M |   0 |7021 |  49k|  47k|  37 | 26 |2264 | 391 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
#   251s|     1 |     2 | 89423 |     - |  5974M |   0 |7021 |  49k|  47k|  37 | 27 |2264 | 393 | 0.000000e+00 | 4.270000e+02 |    Inf | unknown
# d 254s|    48 |    47 | 91488 |  97.3 |linesear|  11 |7021 |  49k|  47k|   0 |  1 |2310 | 393 | 0.000000e+00 | 3.940000e+02 |    Inf | unknown
#   269s|   100 |    95 |105145 | 106.1 |  6052M |  13 |7021 |  49k|  47k| 240 |  1 |2370 | 393 | 0.000000e+00 | 3.940000e+02 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   280s|   200 |   177 |113379 | 103.9 |  6063M |  22 |7021 |  48k|  47k| 376 |  3 |2505 | 393 | 0.000000e+00 | 3.940000e+02 |    Inf |   1.52%
# d 285s|   250 |   211 |115845 | 101.5 |veclendi|  22 |7021 |  48k|  47k|   0 |  1 |2526 | 393 | 0.000000e+00 | 2.940000e+02 |    Inf |   1.79%
#   289s|   300 |   251 |117669 |  98.7 |  6084M |  24 |7021 |  48k|  47k| 571 |  1 |2570 | 393 | 0.000000e+00 | 2.940000e+02 |    Inf |   2.47%
#   295s|   400 |   327 |120539 |  93.2 |  6082M |  26 |7021 |  48k|  47k| 709 |  1 |2689 | 393 | 0.000000e+00 | 2.940000e+02 |    Inf |   2.51%
#   298s|   500 |   384 |122913 |  88.2 |  6083M |  31 |7021 |  48k|  47k| 755 |  1 |2842 | 393 | 0.000000e+00 | 2.940000e+02 |    Inf |   2.52%
#   303s|   600 |   446 |125620 |  84.1 |  6099M |  31 |7021 |  48k|  47k| 898 |  1 |3006 | 393 | 0.000000e+00 | 2.940000e+02 |    Inf |   2.98%
#   312s|   700 |   512 |130122 |  81.6 |  6100M |  31 |7021 |  48k|  47k|1028 |  3 |3185 | 393 | 0.000000e+00 | 2.940000e+02 |    Inf |   3.03%
#   324s|   800 |   574 |149801 |  88.5 |  6121M |  31 |7021 |  48k|   0 |1210 |  0 |3374 | 393 | 0.000000e+00 | 2.940000e+02 |    Inf |   3.11%
#   328s|   900 |   615 |152326 |  84.9 |  6127M |  32 |7021 |  48k|  47k|1299 |  1 |3549 | 393 | 0.000000e+00 | 2.940000e+02 |    Inf |   3.90%
# d 330s|   978 |   540 |154965 |  82.8 |veclendi|  32 |7021 |  48k|  47k|   0 |  1 |3723 | 393 | 0.000000e+00 | 2.520000e+02 |    Inf |   7.27%
#   330s|  1000 |   539 |155401 |  82.0 |  6134M |  32 |7021 |  48k|   0 |1303 |  0 |3772 | 393 | 0.000000e+00 | 2.520000e+02 |    Inf |   8.24%
#   339s|  1100 |   481 |163446 |  82.0 |  6158M |  32 |7021 |  48k|  47k|1430 |  1 |4004 | 393 | 0.000000e+00 | 2.520000e+02 |    Inf |  20.30%
#   352s|  1200 |   380 |170483 |  81.4 |  6169M |  32 |7021 |  48k|  47k|1619 |  1 |4254 | 393 | 0.000000e+00 | 2.520000e+02 |    Inf |  47.69%
#   357s|  1300 |   300 |172090 |  78.4 |  6170M |  32 |7021 |  48k|  47k|1684 |  1 |4466 | 393 | 0.000000e+00 | 2.520000e+02 |    Inf |  63.21%
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 360.00
# Solving Nodes      : 1348 (total of 2229 nodes in 4 runs)
# Primal Bound       : +2.52000000000000e+02 (19 solutions)
# Dual Bound         : +2.52000000000000e+02
# Gap                : 0.00 %
#
# <--------------------------------------------------------------------->
# Results for smt_100_1000.dat:
# 	optimization_time: 403.398785041
# 	objective_value: 252.0
# 	proved_optimality: true
# 	timeout: false
#
# <--------------------------------------------------------------------->
